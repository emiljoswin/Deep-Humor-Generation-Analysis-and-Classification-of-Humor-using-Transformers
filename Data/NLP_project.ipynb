# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cd '/content/drive/My Drive/DSF Project/'
# Out:
# /content/drive/My Drive/DSF Project

# %%
import pandas as pd
import numpy as np
from nltk.tokenize import sent_tokenize, word_tokenize

# %%
all_data = pd.read_csv('/content/drive/My Drive/NLP Project/shortjokes.csv')

# %%
all_data['Joke'].head(4)
# Out:
# 0    [me narrating a documentary about narrators] "...
# 1    Telling my daughter garlic is good for you. Go...
# 2    I've been going through a really rough period ...
# 3    If I could have dinner with anyone, dead or al...
# Name: Joke, dtype: object

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
sentences = []
for i in range(len(all_data)):
  sentences.append(all_data['Joke'].loc[i])

# %%
sentences[2]
# Out:
# "I've been going through a really rough period at work this week It's my own fault for swapping my tampax for sand paper."

# %%
word_list = [word for line in sentences for word in line.split()]

# %%
import re
for i in range(len(word_list)):
    word_list[i] = word_list[i].lower()
    word_list[i] = re.sub(r'\W',' ',word_list[i])

# %%
for i in range(len(word_list)):
  word_list[i] = re.sub(r'\s+','',word_list[i])

# %%
len(word_list)
# Out:
# 4066602

# %%
seen = set()
result = []
for item in word_list:
    if item not in seen:
        seen.add(item)
        result.append(item)

# %%
len(result)
# Out:
# 76173

# %%
from nltk.stem import PorterStemmer 
from nltk.tokenize import word_tokenize 
   
ps = PorterStemmer() 
  

stemmed_dict = []
for w in result: 
   stemmed_dict.append(ps.stem(w))

# %%
stemmed_dict = list(set(stemmed_dict))

# %%
new = []
for i in range(len(words)):
    words[i] = words[i].lower()
    words[i] = re.sub(r'\W',' ',words[i])
    words [i] = re.sub(r'\s+','',words[i])
    new.append(ps.stem(words[i]))

# %%
new
# Out:
# ['i', 'am', 'come']

# %%
places = []

# open file and read the content in a list
with open('/content/drive/My Drive/NLP Project/news_2015.txt', 'r') as filehandle:
    for line in filehandle:
        # remove linebreak which is the last character of the string
        currentPlace = line[:-1]

        # add item to the list
        places.append(currentPlace)

# %%
len(places)
# Out:
# 27236445

# %%
import time
word_list= []
temp_list = []
final_list = []
start_time = time.time()

for i in range(2000000):
  # if i==0:
  word_list = places[i].split()
  # print (word_list)
  temp_list = []
  for j in range(len(word_list)):
    word_list[j] = word_list[j].lower()
    word_list[j] = re.sub(r'\W',' ',word_list[j])
    word_list[j] = re.sub(r'\s+','',word_list[j])
    temp_list.append(ps.stem(word_list[j]))
  final_list.append(temp_list)
  if(i%10000==0):
    print ("Counter: ",i/10000)
    elapsed_time = time.time() - start_time
    print (elapsed_time)
# Out:
# Counter:  0.0
# 0.0016446113586425781
# Counter:  1.0
# 3.353705883026123
# Counter:  2.0
# 6.7815468311309814
# Counter:  3.0
# 10.13065218925476
# Counter:  4.0
# 15.615655422210693
# Counter:  5.0
# 19.976467609405518
# Counter:  6.0
# 23.548598051071167
# Counter:  7.0
# 26.89894676208496
# Counter:  8.0
# 30.329588651657104
# Counter:  9.0
# 33.78731036186218
# Counter:  10.0
# 37.15205383300781
# Counter:  11.0
# 40.54483413696289
# Counter:  12.0
# 43.95672535896301
# Counter:  13.0
# 49.17667865753174
# Counter:  14.0
# 52.573569774627686
# Counter:  15.0
# 55.8986029624939
# Counter:  16.0
# 59.30868196487427
# Counter:  17.0
# 62.74546980857849
# Counter:  18.0
# 66.1290431022644
# Counter:  19.0
# 69.52679800987244
# Counter:  20.0
# 72.91420269012451
# Counter:  21.0
# 76.35721278190613
# Counter:  22.0
# 79.73517441749573
# Counter:  23.0
# 84.79397702217102
# Counter:  24.0
# 88.21349358558655
# Counter:  25.0
# 91.61636114120483
# Counter:  26.0
# 94.99007868766785
# ...

# %%
len(final_list[5])
# Out:
# 18

# %%
type(stemmed_dict)
# Out:
# list

# %%
set_stemmed = set(stemmed_dict)

# %%
places[0:2]
# Out:
# ['Turn out is expected to be around 75 percent or more.',
#  'Two memorials are being proposed after consultation with parents.']

# %%
new_list[0]
# Out:
# 'turn'

# %%
result = []

# %%
places[1000]
# Out:
# 'Anders Ericsson studied elite musicians at the Berlin Academy of Music and is credited with the now wildly popular notion that it takes 10,000 hours of deliberate practice to master anything.'

# %%
final_list[1000]
# Out:
# ['ander',
#  'ericsson',
#  'studi',
#  'elit',
#  'musician',
#  'at',
#  'the',
#  'berlin',
#  'academi',
#  'of',
#  'music',
#  'and',
#  'is',
#  'credit',
#  'with',
#  'the',
#  'now',
#  'wildli',
#  'popular',
#  'notion',
#  'that',
#  'it',
#  'take',
#  '10000',
#  'hour',
#  'of',
#  'deliber',
#  'practic',
#  'to',
#  'master',
#  'anyth']

# %%
threshold = 0.9
num = 2000000

# %%
result = []
start_time = time.time()
for i in range(len(places[:num])):
  count  = len(set(final_list[i]).intersection(stemmed_dict))
  if count/len(final_list[i]) >= threshold:
    result.append(places[i])
  if(i%10000==0):
    print ("Counter: ",i/10000)
    elapsed_time = time.time() - start_time
    print (elapsed_time)
# Out:
# Counter:  0.0
# 0.11109375953674316
# Counter:  1.0
# 22.98218035697937
# Counter:  2.0
# 45.24860382080078
# Counter:  3.0
# 66.62038493156433
# Counter:  4.0
# 88.61563539505005
# Counter:  5.0
# 110.57165741920471
# Counter:  6.0
# 132.73478651046753
# Counter:  7.0
# 154.3855698108673
# Counter:  8.0
# 175.8981592655182
# Counter:  9.0
# 196.5933473110199
# Counter:  10.0
# 218.52847957611084
# Counter:  11.0
# 239.82730174064636
# Counter:  12.0
# 260.87961649894714
# Counter:  13.0
# 282.23701786994934
# Counter:  14.0
# 302.6688027381897
# Counter:  15.0
# 322.82630586624146
# Counter:  16.0
# 343.16293358802795
# Counter:  17.0
# 363.3845000267029
# Counter:  18.0
# 383.5571942329407
# Counter:  19.0
# 404.50978899002075
# Counter:  20.0
# 425.21204924583435
# Counter:  21.0
# 445.1516671180725
# Counter:  22.0
# 466.59631299972534
# Counter:  23.0
# 487.35499453544617
# Counter:  24.0
# 507.7481617927551
# Counter:  25.0
# 528.4997892379761
# Counter:  26.0
# ...

# %%
len(result), result
# Out:
# (5,
#  ['Turn out is expected to be around 75 percent or more.',
#   'Two memorials are being proposed after consultation with parents.',
#   "But, after 'a valiant effort', he finally gave up the 'good fight in dramatic fashion.'",
#   'He would also close a big loophole that enables many wealthy estates to avoid paying inheritance taxes altogether.',
#   'In regards to gender dysphoria, this is a highly specialised area.'])

# %%
len(result)
# Out:
# 979712

# %%
% pwd
# output.close()
# Out:
# '/content/drive/My Drive/DSF Project'

# %%
with open("news_non_joke.txt", 'w') as output:
    for row in result:
        output.write(str(row) + '\n')

# %%
set(final_list[0]).intersection(stemmed_dict)
# Out:
# {'75',
#  'around',
#  'be',
#  'expect',
#  'is',
#  'more',
#  'or',
#  'out',
#  'percent',
#  'to',
#  'turn'}
