# %%
from google.colab import drive
drive.mount._DEBUG = True
drive.mount('/content/drive')
# Out:
# export PS1="root@b04905a6e0ef-4bc19d815a154aadbba97daa848c13fa: "
# bash: cannot set terminal process group (-1): Inappropriate ioctl for device
# bash: no job control in this shell
# root@b04905a6e0ef:/content# root@b04905a6e0ef-4bc19d815a154aadbba97daa848c13fa: umount -f /content/drive || umount /content/drive; pkill -9 -x drive
# umount: /content/drive: no mount point specified.
# umount: /content/drive: no mount point specified.
# root@b04905a6e0ef-4bc19d815a154aadbba97daa848c13fa: ( while `sleep 0.5`; do if [[ -d "/content/drive" && "$(ls -A /content/drive)" != "" ]]; then echo "google.colab.drive MOUNTED"; break; fi; done ) &
# [1] 333
# ...

# %%
# !cp -r /content/drive/My\ Drive/nlp_project/bert_pytorch_e_1.bin .

# %%
import torch

# %%
import sys
# !test -d bertviz_repo && echo "FYI: bertviz_repo directory already exists, to pull latest version uncomment this line: !rm -r bertviz_repo"
# !rm -r bertviz_repo # Uncomment if you need a clean pull from repo
# !test -d bertviz_repo || git clone https://github.com/jessevig/bertviz bertviz_repo
if not 'bertviz_repo' in sys.path:
  sys.path += ['bertviz_repo']
# !pip install regex
# !pip install transformers
# Out:
# Cloning into 'bertviz_repo'...
# remote: Enumerating objects: 94, done.
# remote: Counting objects: 100% (94/94), done.
# remote: Compressing objects: 100% (65/65), done.
# remote: Total 1013 (delta 57), reused 64 (delta 29), pack-reused 919
# Receiving objects: 100% (1013/1013), 98.72 MiB | 12.03 MiB/s, done.
# Resolving deltas: 100% (647/647), done.
# ...
#      |████████████████████████████████| 645kB 2.8MB/s
# ...
#      |████████████████████████████████| 368kB 2.8MB/s
# ...
#      |████████████████████████████████| 1.0MB 68.4MB/s
# ...
#      |████████████████████████████████| 860kB 62.8MB/s
# ...
#   Created wheel for sacremoses: filename=sacremoses-0.0.35-cp36-none-any.whl size=883999 sha256=13688a18f48575dee15842dc3791f06ed861c1b848e2132b94190bdb7a4223fc
#   Stored in directory: /root/.cache/pip/wheels/63/2a/db/63e2909042c634ef551d0d9ac825b2b0b32dede4a6d87ddc94
# Successfully built sacremoses
# ...

# %%
from bertviz import model_view
from transformers import BertTokenizer, BertModel, BertForSequenceClassification
# Out:
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>

# %%
def call_html():
  import IPython
  display(IPython.core.display.HTML('''
        <script src="/static/components/requirejs/require.js"></script>
        <script>
          requirejs.config({
            paths: {
              base: '/static/base',
              "d3": "https://cdnjs.cloudflare.com/ajax/libs/d3/5.7.0/d3.min",
              jquery: '//ajax.googleapis.com/ajax/libs/jquery/2.0.0/jquery.min',
            },
          });
        </script>
        '''))

# %%
model_trained = '/content/bert_pytorch_e_1.bin'


model_version = 'bert-base-uncased'
do_lower_case = True
model = BertModel.from_pretrained(model_version, output_attentions=True)

ob = torch.load(model_trained)
model.load_state_dict(ob)

tokenizer = BertTokenizer.from_pretrained(model_version, do_lower_case=do_lower_case)
sentence_a = "The cat sat on the mat"
sentence_b = "The cat lay on the rug"
inputs = tokenizer.encode_plus(sentence_a, sentence_b, return_tensors='pt', add_special_tokens=True)
token_type_ids = inputs['token_type_ids']
input_ids = inputs['input_ids']
attention = model(input_ids, token_type_ids=token_type_ids)[-1]
input_id_list = input_ids[0].tolist() # Batch index 0
tokens = tokenizer.convert_ids_to_tokens(input_id_list)
call_html()
model_view(attention, tokens)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-9-68036e377743> in <module>()
#       7
#       8 ob = torch.load(model_trained)
# ----> 9 model.load_state_dict(ob)
#      10
#      11 tokenizer = BertTokenizer.from_pretrained(model_version, do_lower_case=do_lower_case)
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py in load_state_dict(self, state_dict, strict)
#     837         if len(error_msgs) > 0:
#     838             raise RuntimeError('Error(s) in loading state_dict for {}:\n\t{}'.format(
# --> 839                                self.__class__.__name__, "\n\t".join(error_msgs)))
#     840         return _IncompatibleKeys(missing_keys, unexpected_keys)
#     841
#
# RuntimeError: Error(s) in loading state_dict for BertModel:
# ...

# %% [markdown]
# #### Load the Fine-tuned Bert

# %%
model_trained_loc = '/content/bert_pytorch_e_1.bin'
model_version = 'bert-base-uncased'
do_lower_case = True

ob = torch.load(model_trained_loc)

model_tuned = BertForSequenceClassification.from_pretrained(model_version, 
                                                      output_attentions=True,
                                                      state_dict=ob,
                                                      num_labels=2)

tokenizer = BertTokenizer.from_pretrained(model_version, do_lower_case=do_lower_case)
# Out:
# ...
# 100%|██████████| 231508/231508 [00:00<00:00, 400546.70B/s]

# %%
#### NO JOKE

sentence_a = "Google News is a news aggregator app developed by Google"

sentence_b = None

inputs = tokenizer.encode_plus(sentence_a, sentence_b, return_tensors='pt', add_special_tokens=True)

token_type_ids = inputs['token_type_ids']
input_ids = inputs['input_ids']

attention = model_tuned(input_ids, token_type_ids=token_type_ids)[-1]

input_id_list = input_ids[0].tolist() # Batch index 0
tokens = tokenizer.convert_ids_to_tokens(input_id_list)
call_html()
model_view(attention, tokens)
# Out:
#         <script src="/static/components/requirejs/require.js"></script>
#         <script>
#           requirejs.config({
#             paths: {
#               base: '/static/base',
#               "d3": "https://cdnjs.cloudflare.com/ajax/libs/d3/5.7.0/d3.min",
#               jquery: '//ajax.googleapis.com/ajax/libs/jquery/2.0.0/jquery.min',
#             },
#           });
#         </script>
#           <div id='vis'></div>

# %%
#### JOKE SENTENCE


sentence_a = "What do you call a dinosaur with explosive diarrhea? A shitty-sore-ass."
sentence_b = None
inputs = tokenizer.encode_plus(sentence_a, sentence_b, return_tensors='pt', add_special_tokens=True)

token_type_ids = inputs['token_type_ids']
input_ids = inputs['input_ids']
attention = model_tuned(input_ids, token_type_ids=token_type_ids)[-1]

input_id_list = input_ids[0].tolist() # Batch index 0z
tokens = tokenizer.convert_ids_to_tokens(input_id_list)
call_html()
model_view(attention, tokens)
# Out:
#         <script src="/static/components/requirejs/require.js"></script>
#         <script>
#           requirejs.config({
#             paths: {
#               base: '/static/base',
#               "d3": "https://cdnjs.cloudflare.com/ajax/libs/d3/5.7.0/d3.min",
#               jquery: '//ajax.googleapis.com/ajax/libs/jquery/2.0.0/jquery.min',
#             },
#           });
#         </script>
#           <div id='vis'></div>

# %%
#### JOKE SENTENCE 2


sentence_a = "How much do Americans like racist jokes? Enough to make one President."
sentence_b = None
inputs = tokenizer.encode_plus(sentence_a, sentence_b, return_tensors='pt', add_special_tokens=True)

token_type_ids = inputs['token_type_ids']
input_ids = inputs['input_ids']
attention = model_tuned(input_ids, token_type_ids=token_type_ids)[-1]

input_id_list = input_ids[0].tolist() # Batch index 0
tokens = tokenizer.convert_ids_to_tokens(input_id_list)
call_html()
model_view(attention, tokens)
# Out:
#         <script src="/static/components/requirejs/require.js"></script>
#         <script>
#           requirejs.config({
#             paths: {
#               base: '/static/base',
#               "d3": "https://cdnjs.cloudflare.com/ajax/libs/d3/5.7.0/d3.min",
#               jquery: '//ajax.googleapis.com/ajax/libs/jquery/2.0.0/jquery.min',
#             },
#           });
#         </script>
#           <div id='vis'></div>

# %%
#### NO - JOKE SENTENCE 2


sentence_a = "This country was build with sweat and blood of its early founding fathers"
sentence_b = None
inputs = tokenizer.encode_plus(sentence_a, sentence_b, return_tensors='pt', add_special_tokens=True)

token_type_ids = inputs['token_type_ids']
input_ids = inputs['input_ids']
attention = model_tuned(input_ids, token_type_ids=token_type_ids)[-1]

input_id_list = input_ids[0].tolist() # Batch index 0
tokens = tokenizer.convert_ids_to_tokens(input_id_list)
call_html()
model_view(attention, tokens)
# Out:
#         <script src="/static/components/requirejs/require.js"></script>
#         <script>
#           requirejs.config({
#             paths: {
#               base: '/static/base',
#               "d3": "https://cdnjs.cloudflare.com/ajax/libs/d3/5.7.0/d3.min",
#               jquery: '//ajax.googleapis.com/ajax/libs/jquery/2.0.0/jquery.min',
#             },
#           });
#         </script>
#           <div id='vis'></div>
